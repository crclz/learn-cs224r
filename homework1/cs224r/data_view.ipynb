# %%
import pickle

# %%
with open("expert_data/expert_data_Ant-v4.pkl", 'rb') as f:
    obj = pickle.load(f)
# Out:
# C:\Users\ThePlayer\AppData\Local\Temp\ipykernel_22492\784647418.py:2: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   obj = pickle.load(f)

# %%
print(len(obj))
a0, a1 = obj
print(a0.__class__, a1.__class__)

len(a1['observation'])
print('a0 keys', list(a0.keys()))
print('a1 keys', list(a1.keys()))
# Out:
# 2
# <class 'dict'> <class 'dict'>
# a0 keys ['observation', 'image_obs', 'reward', 'action', 'next_observation', 'terminal']
# a1 keys ['observation', 'image_obs', 'reward', 'action', 'next_observation', 'terminal']

# %%
a1['observation'].shape
# Out:
# (1000, 111)

# %%
import numpy as np

# %%
a = np.arange(10) * 100
print("a", a)
permuted = np.random.permutation(10)
a[permuted]
# Out:
# a [  0 100 200 300 400 500 600 700 800 900]
# array([700, 300, 800,   0, 600, 900, 400, 100, 200, 500])
