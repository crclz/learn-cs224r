# %%
import torch

# %%
torch.zeros((5,3)).min(1).values.shape
# Out:
# torch.Size([5])

# %%
a = torch.zeros((5,1)) * torch.zeros((5,))
a.shape
# Out:
# torch.Size([5, 5])

# %%
a = torch.zeros((25,1)).squeeze(-1).squeeze(-1)
a.shape
# Out:
# torch.Size([25])

# %%
a = torch.zeros((5,1, 1))
torch.concat([a,a,a], 1).shape
# Out:
# torch.Size([5, 3, 1])
