# %%
import torch

# %%
(batch_size, action_dim) = (32, 4)
actions = torch.zeros((batch_size, 1)).long()
qs = torch.zeros((batch_size, action_dim))
qs.gather(1, actions).shape
# Out:
# torch.Size([32, 1])

# %%
torch.zeros((32,5)).sum(1, keepdims=True).shape
# Out:
# torch.Size([32, 1])

# %%
import torch.nn as nn

nn.MSELoss()(torch.zeros((32,1)), torch.zeros((32,1))).shape
# Out:
# torch.Size([])
