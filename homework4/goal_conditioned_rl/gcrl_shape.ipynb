# %%
import numpy as np

# %%
np.concatenate([np.zeros(3), np.zeros(3)]).shape
# Out:
# (6,)

# %%
import torch

# %%
torch.zeros((3)).unsqueeze(0).shape
# Out:
# torch.Size([1, 3])

# %%
torch.zeros((1,5)).argmax(1).item()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 torch.zeros((1,5)).item()
#
# RuntimeError: a Tensor with 5 elements cannot be converted to Scalar
